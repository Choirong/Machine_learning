# %%
# Mnist data set 불러오기

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

mnist = tf.keras.datasets.mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)

nsamples, nx, ny = X_train.shape
X_train = X_train.reshape((nsamples,nx*ny))
nsamples, nx, ny = X_test.shape
X_test = X_test.reshape((nsamples,nx*ny))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)
# (60000, 784) (60000,) (10000, 784) (10000,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

for C, marker in zip([0.001, 1, 100], ['o', '^', 'v']):
    lr_l1 = LogisticRegression(solver='liblinear', C=C, penalty="l1", max_iter=500).fit(X_train, y_train)
    print("C={:.3f} 인 l1 로지스틱 회귀의 훈련 정확도: {:.2f}".format(
          C, lr_l1.score(X_train, y_train)))
    print("C={:.3f} 인 l1 로지스틱 회귀의 테스트 정확도: {:.2f}".format(
          C, lr_l1.score(X_test, y_test)))
    plt.plot(lr_l1.coef_.T, marker, label="C={:.3f}".format(C))

#plt.xticks(range(cancer.data.shape[1]), cancer.feature_names, rotation=90)
#xlims = plt.xlim()
#plt.hlines(0, xlims[0], xlims[1])
#plt.xlim(xlims)
#plt.xlabel("특성")
#plt.ylabel("계수 크기")

plt.ylim(-5, 5)
plt.legend(loc=3)
plt.show() # 책에는 없음
# Out:
# C=0.001 인 l1 로지스틱 회귀의 훈련 정확도: 0.76
# C=0.001 인 l1 로지스틱 회귀의 테스트 정확도: 0.76
# C=1.000 인 l1 로지스틱 회귀의 훈련 정확도: 0.93
# C=1.000 인 l1 로지스틱 회귀의 테스트 정확도: 0.92
# C=100.000 인 l1 로지스틱 회귀의 훈련 정확도: 0.93
# C=100.000 인 l1 로지스틱 회귀의 테스트 정확도: 0.92

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

for C in [0.001, 1, 100]:
    lr_l1 = LogisticRegression(solver='liblinear', C=C, penalty="l1", max_iter=500).fit(X_train, y_train)
    print("C={:.3f} 인 l1 로지스틱 회귀의 훈련 정확도: {:.4f}".format(
          C, lr_l1.score(X_train, y_train)))
    print("C={:.3f} 인 l1 로지스틱 회귀의 테스트 정확도: {:.4f}".format(
          C, lr_l1.score(X_test, y_test)))
# Out:
# C=0.001 인 l1 로지스틱 회귀의 훈련 정확도: 0.7581
# C=0.001 인 l1 로지스틱 회귀의 테스트 정확도: 0.7643
# C=1.000 인 l1 로지스틱 회귀의 훈련 정확도: 0.9280
# C=1.000 인 l1 로지스틱 회귀의 테스트 정확도: 0.9194
# C=100.000 인 l1 로지스틱 회귀의 훈련 정확도: 0.9318
# C=100.000 인 l1 로지스틱 회귀의 테스트 정확도: 0.9175

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

for C in [0.001, 1, 100]:
    lr_l2 = LogisticRegression(solver='liblinear', C=C, penalty="l2", max_iter=500).fit(X_train, y_train)
    print("C={:.3f} 인 l2 로지스틱 회귀의 훈련 정확도: {:.4f}".format(
          C, lr_l1.score(X_train, y_train)))
    print("C={:.3f} 인 l2 로지스틱 회귀의 테스트 정확도: {:.4f}".format(
          C, lr_l1.score(X_test, y_test)))
# Out:
# C=0.001 인 l2 로지스틱 회귀의 훈련 정확도: 0.9318
# C=0.001 인 l2 로지스틱 회귀의 테스트 정확도: 0.9175
# C=1.000 인 l2 로지스틱 회귀의 훈련 정확도: 0.9318
# C=1.000 인 l2 로지스틱 회귀의 테스트 정확도: 0.9175
# C=100.000 인 l2 로지스틱 회귀의 훈련 정확도: 0.9318
# C=100.000 인 l2 로지스틱 회귀의 테스트 정확도: 0.9175

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

for C in [0.001, 1, 100]:
    lr_l1 = LogisticRegression(solver='lbfgs', C=C, penalty="none", max_iter=500).fit(X_train, y_train)
    print("C={:.3f} 인 l1 로지스틱 회귀의 훈련 정확도: {:.4f}".format(
          C, lr_l1.score(X_train, y_train)))
    print("C={:.3f} 인 l1 로지스틱 회귀의 테스트 정확도: {:.4f}".format(
          C, lr_l1.score(X_test, y_test)))
# Out:
# c:\users\최동현\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\users\최동현\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=0.001 인 l1 로지스틱 회귀의 훈련 정확도: 0.9421
# C=0.001 인 l1 로지스틱 회귀의 테스트 정확도: 0.9228
# c:\users\최동현\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=1.000 인 l1 로지스틱 회귀의 훈련 정확도: 0.9421
# C=1.000 인 l1 로지스틱 회귀의 테스트 정확도: 0.9228
# c:\users\최동현\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\users\최동현\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=100.000 인 l1 로지스틱 회귀의 훈련 정확도: 0.9421
# C=100.000 인 l1 로지스틱 회귀의 테스트 정확도: 0.9228

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

for C in [0.001, 1, 100]:
    lr_l2 = LogisticRegression(solver='lbfgs', C=C, penalty="l2", max_iter=500).fit(X_train, y_train)
    print("C={:.3f} 인 l2 로지스틱 회귀의 훈련 정확도: {:.4f}".format(
          C, lr_l1.score(X_train, y_train)))
    print("C={:.3f} 인 l2 로지스틱 회귀의 테스트 정확도: {:.4f}".format(
          C, lr_l1.score(X_test, y_test)))
# Out:
# C=0.001 인 l2 로지스틱 회귀의 훈련 정확도: 0.9421
# C=0.001 인 l2 로지스틱 회귀의 테스트 정확도: 0.9228
# c:\users\최동현\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=1.000 인 l2 로지스틱 회귀의 훈련 정확도: 0.9421
# C=1.000 인 l2 로지스틱 회귀의 테스트 정확도: 0.9228
# c:\users\최동현\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=100.000 인 l2 로지스틱 회귀의 훈련 정확도: 0.9421
# C=100.000 인 l2 로지스틱 회귀의 테스트 정확도: 0.9228

# %%
# LogisticRegression

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

L_Reg = LogisticRegression().fit(X_train, y_train)

print("Training set score: {:.4f}".format(L_Reg.score(X_train, y_train)))
print("Test set score: {:.4f}".format(L_Reg.score(X_test, y_test)))
# Out:
# c:\users\최동현\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training set score: 0.9351
# Test set score: 0.9258

# %%
#  K-NN classifiers 
# k=2

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 2).fit(X_train, y_train)

print("Training set score: {:.4f}".format(knn.score(X_train, y_train)))
print("Test set score: {:.4f}".format(knn.score(X_test, y_test)))
# Out:
# Training set score: 0.9857
# Test set score: 0.9627

# %%
#  K-NN classifiers 
# k=3

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 3).fit(X_train, y_train)

print("Training set score: {:.4f}".format(knn.score(X_train, y_train)))
print("Test set score: {:.4f}".format(knn.score(X_test, y_test)))
# Out:
# Training set score: 0.9867
# Test set score: 0.9705

# %%
#  K-NN classifiers 
# k=4

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 4).fit(X_train, y_train)

print("Training set score: {:.4f}".format(knn.score(X_train, y_train)))
print("Test set score: {:.4f}".format(knn.score(X_test, y_test)))
# Out:
# Training set score: 0.9830
# Test set score: 0.9682

# %%
#  K-NN classifiers 
# k=5

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 5).fit(X_train, y_train)

print("Training set score: {:.4f}".format(knn.score(X_train, y_train)))
print("Test set score: {:.4f}".format(knn.score(X_test, y_test)))
# Out:
# Training set score: 0.9819
# Test set score: 0.9688

# %%
#  K-NN classifiers 
# k=6

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 6).fit(X_train, y_train)

print("Training set score: {:.4f}".format(knn.score(X_train, y_train)))
print("Test set score: {:.4f}".format(knn.score(X_test, y_test)))
# Out:
# Training set score: 0.9797
# Test set score: 0.9677

# %%
# SVM classifiers
# kernel='rbf'

from sklearn.svm import SVC

SVM = SVC(kernel='rbf', C=2).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9957
# Test set score: 0.9831

# %%
# SVM classifiers
# kernel='rbf'

from sklearn.svm import SVC

SVM = SVC(kernel='rbf', C=1.0, gamma='auto').fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9430
# Test set score: 0.9446

# %%
# SVM classifiers
# kernel='rbf'

from sklearn.svm import SVC

SVM = SVC(kernel='rbf', C=5, gamma='auto').fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9617
# Test set score: 0.9561

# %%
# SVM classifiers
# kernel='rbf'

from sklearn.svm import SVC

SVM = SVC(kernel='rbf', C=1.0, gamma='auto').fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))

# %%
# SVM classifiers
# kernel='linear'

from sklearn.svm import SVC

SVM = SVC(kernel='linear', C=1).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9708
# Test set score: 0.9404

# %%
# SVM classifiers
# kernel='linear'

from sklearn.svm import SVC

SVM = SVC(kernel='linear', C=0.1).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9588
# Test set score: 0.9472

# %%
# SVM classifiers
# kernel='linear'

from sklearn.svm import SVC

SVM = SVC(kernel='linear', C=0.01).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9451
# Test set score: 0.9443

# %%
# SVM classifiers
# kernel='linear'

from sklearn.svm import SVC

SVM = SVC(kernel='linear', C=0.001).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9271
# Test set score: 0.9302

# %%
# SVM classifiers
# kernel='linear'

from sklearn.svm import SVC

SVM = SVC(kernel='linear', C=0.0001).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.8908
# Test set score: 0.9007

# %%
# SVM classifiers
# kernel='linear'

from sklearn.svm import SVC

SVM = SVC(kernel='linear', C=0.00001).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))

# %%
# SVM classifiers
# kernel='linear'

from sklearn.svm import SVC

SVM = SVC(kernel='linear', C=5).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9775
# Test set score: 0.9338

# %%
# SVM classifiers
# kernel='linear'

from sklearn.svm import SVC

SVM = SVC(kernel='linear', C=10).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9797
# Test set score: 0.9310

# %%
# SVM classifiers
# kernel='poly' 오래 걸림

from sklearn.svm import SVC

SVM = SVC(kernel='poly', C=1).fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.9916
# Test set score: 0.9771

# %%
# SVM classifiers
# kernel='poly' 오래 걸림

from sklearn.svm import SVC

SVM = SVC(kernel='poly', C=2, gamma='auto').fit(X_train, y_train)

print("Training set score: {:.4f}".format(SVM.score(X_train, y_train)))
print("Test set score: {:.4f}".format(SVM.score(X_test, y_test)))
# Out:
# Training set score: 0.7137
# Test set score: 0.7414

# %%
# Random forest classifiers

from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=5, random_state=2) #n_estimators 생성할 트리 개수
forest.fit(X_train, y_train)

print("Training set score: {:.4f}".format(forest.score(X_train, y_train)))
print("Test set score: {:.4f}".format(forest.score(X_test, y_test)))
# Out:
# Training set score: 0.9938
# Test set score: 0.9177

# %%
# Random forest classifiers

from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=10, random_state=2) #n_estimators 생성할 트리 개수
forest.fit(X_train, y_train)

print("Training set score: {:.4f}".format(forest.score(X_train, y_train)))
print("Test set score: {:.4f}".format(forest.score(X_test, y_test)))
# Out:
# Training set score: 0.9991
# Test set score: 0.9481

# %%
# Random forest classifiers

from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=20, random_state=2) #n_estimators 생성할 트리 개수
forest.fit(X_train, y_train)

print("Training set score: {:.4f}".format(forest.score(X_train, y_train)))
print("Test set score: {:.4f}".format(forest.score(X_test, y_test)))
# Out:
# Training set score: 0.9999
# Test set score: 0.9616

# %%
for n_estimators in [1, 5, 10, 20, 50, 100]:
    forest = RandomForestClassifier(n_estimators=n_estimators, random_state=2).fit(X_train, y_train)
    print("n_estimators={:.1f} 인 RandomForest의 훈련 정확도: {:.4f}".format(
          n_estimators, forest.score(X_train, y_train)))
    print("n_estimators={:.1f} 인 RandomForest의 테스트 정확도: {:.4f}".format(
          n_estimators, forest.score(X_test, y_test)))
# Out:
# n_estimators=1.0 인 RandomForest의 훈련 정확도: 0.9330
# n_estimators=1.0 인 RandomForest의 테스트 정확도: 0.8251
# n_estimators=5.0 인 RandomForest의 훈련 정확도: 0.9938
# n_estimators=5.0 인 RandomForest의 테스트 정확도: 0.9177
# n_estimators=10.0 인 RandomForest의 훈련 정확도: 0.9991
# n_estimators=10.0 인 RandomForest의 테스트 정확도: 0.9481
# n_estimators=20.0 인 RandomForest의 훈련 정확도: 0.9999
# n_estimators=20.0 인 RandomForest의 테스트 정확도: 0.9616
# n_estimators=50.0 인 RandomForest의 훈련 정확도: 1.0000
# n_estimators=50.0 인 RandomForest의 테스트 정확도: 0.9679
# n_estimators=100.0 인 RandomForest의 훈련 정확도: 1.0000
# n_estimators=100.0 인 RandomForest의 테스트 정확도: 0.9698

# %%
for n_estimators in [1000, 5000, 10000]:
    forest = RandomForestClassifier(n_estimators=n_estimators, random_state=2).fit(X_train, y_train)
    print("n_estimators={:.1f} 인 RandomForest의 훈련 정확도: {:.4f}".format(
          n_estimators, forest.score(X_train, y_train)))
    print("n_estimators={:.1f} 인 RandomForest의 테스트 정확도: {:.4f}".format(
          n_estimators, forest.score(X_test, y_test)))
# Out:
# n_estimators=1000.0 인 RandomForest의 훈련 정확도: 1.0000
# n_estimators=1000.0 인 RandomForest의 테스트 정확도: 0.9711
